# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 윈도우 기본 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 마이너스 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel('C:\\Users\\User\\Documents\\OneDrive - SangMyung University\\모멘텀\\오합지존 프로젝트\\BIGCONTEST\\public\\최종 데이터셋.xlsx')
df
# Out:
#        Unnamed: 0     가맹점구분번호    기준년월  가맹점 운영개월수 구간  매출금액 구간  매출건수 구간  \
# 0               0  000F03E44A  202301             5        6        5
# 1               1  000F03E44A  202302             5        6        6
# 2               2  002816BA73  202404             2        3        4
# 3               3  002816BA73  202411             2        3        4
# 4               4  002816BA73  202406             2        4        4
# ...           ...         ...     ...           ...      ...      ...
# 83916       86584  63D56CEF99  202303             4        2        3
# 83917       86585  A2D9C941A9  202304             5        2        1
# 83918       86586  A7C2307794  202303             2        2        2
# 83919       86588  C59F032CAC  202406             1        2        2
# 83920       86589  F46D45E328  202302             2        2        3
#
#        유니크 고객 수 구간  객단가 구간    취소율 구간  배달매출금액 비율  ...  유동인구 이용 고객 비율  \
# 0                5       4       1.0  -999999.9  ...          100.0
# 1                6       6 -999999.9  -999999.9  ...      -999999.9
# 2                4       2       6.0  -999999.9  ...           52.4
# 3                4       2       6.0  -999999.9  ...           76.9
# 4                4       2       1.0  -999999.9  ...           69.6
# ...            ...     ...       ...        ...  ...            ...
# 83916            3       3       4.0       34.7  ...           53.8
# 83917            1       6       2.0        2.6  ...           24.4
# 83918            2       3       1.0       19.2  ...           55.9
# 83919            2       4       2.0       24.0  ...           48.7
# 83920            3       3       1.0       12.8  ...           50.0
#
#                        가맹점주소           가맹점명      브랜드구분코드   가맹점지역          업종  \
# 0        서울특별시 성동구 왕십리로4가길 9           육육**  중식-딤섬/중식만두1  서울 성동구  중식-딤섬/중식만두
# 1        서울특별시 성동구 왕십리로4가길 9           육육**  중식-딤섬/중식만두1  서울 성동구  중식-딤섬/중식만두
# 2         서울 성동구 청계천로10나길 78  자갈***********       요리주점52  서울 성동구        요리주점
# 3         서울 성동구 청계천로10나길 78  자갈***********       요리주점52  서울 성동구        요리주점
# 4         서울 성동구 청계천로10나길 78  자갈***********       요리주점52  서울 성동구        요리주점
# ...                      ...            ...          ...     ...         ...
# 83916  서울특별시 성동구 무학봉26길 12-1           곱순**   한식-육류/고기34  서울 성동구    한식-육류/고기
# 83917      서울특별시 성동구 행당로5길 2  메가***********       커피전문점2  서울 성동구       커피전문점
# 83918        서울 성동구 한림말1길 8.        콩물*****     한식-두부요리1  서울 성동구     한식-두부요리
# 83919      서울 성동구 왕십리로 223-1          밸런***    샌드위치/토스트1  서울 성동구    샌드위치/토스트
# 83920     서울 성동구 용답중앙15길 13.             미*        중식당29  서울 성동구         중식당
#
#         상권       개설일       폐업일       브랜드이름
# 0       뚝섬  20220225 -999999.9  중식-딤섬/중식만두
# 1       뚝섬  20220225 -999999.9  중식-딤섬/중식만두
# 2      마장동  20140507 -999999.9        요리주점
# 3      마장동  20140507 -999999.9        요리주점
# 4      마장동  20140507 -999999.9        요리주점
# ...    ...       ...       ...         ...
# 83916  왕십리  20200529 -999999.9    한식-육류/고기
# 83917  왕십리  20220823 -999999.9       커피전문점
# 83918   옥수  20140508 -999999.9     한식-두부요리
# 83919  한양대  20090421 -999999.9    샌드위치/토스트
# 83920  답십리  20131128 -999999.9         중식당
#
# [83921 rows x 40 columns]

# %%
df['가맹점구분번호'].nunique()
# Out:
# 4042

# %%
a = df.groupby('업종')['가맹점구분번호'].nunique().reset_index(name = '가맹점수')
a.to_excel('업종별 가맹점수.xlsx', index = False)

# %%
업종_상권분포 = (
    df.groupby(['업종', '상권'])['가맹점구분번호']
          .nunique()
          .reset_index(name='가맹점수')
)

업종_상권분포['비율(%)'] = (
    업종_상권분포.groupby('업종')['가맹점수']
             .transform(lambda x: x / x.sum() * 100))
업종_상권분포
# Out:
#         업종      상권  가맹점수      비율(%)
# 0     건강식품    금남시장     3  25.000000
# 1     건강식품     마장동     1   8.333333
# 2     건강식품  압구정로데오     1   8.333333
# 3     건강식품     왕십리     4  33.333333
# 4     건강식품  장한평자동차     1   8.333333
# ..     ...     ...   ...        ...
# 461  호프/맥주      성수    16  19.277108
# 462  호프/맥주     신금호     3   3.614458
# 463  호프/맥주      옥수     2   2.409639
# 464  호프/맥주     왕십리    22  26.506024
# 465  호프/맥주     한양대    13  15.662651
#
# [466 rows x 4 columns]

# %%
import pandas as pd

# 1️⃣ 업종별·상권별 가맹점 수 계산
업종_상권분포 = (
    df.groupby(['업종', '상권'])['가맹점구분번호']
      .nunique()
      .reset_index(name='가맹점수')
)

# 2️⃣ 업종별 상권비율 계산 (업종 내 비중)
업종_상권분포['상권비율(%)'] = (
    업종_상권분포.groupby('업종')['가맹점수']
             .transform(lambda x: x / x.sum() * 100)
)

# ------------------------------------------------
# 3️⃣ 업종 기준 출력 함수
# ------------------------------------------------

def 업종기준_출력(업종명, topn=None):
    subset = 업종_상권분포[업종_상권분포['업종'] == 업종명] \
        .sort_values('가맹점수', ascending=False)
    
    # 전체 가맹점 수
    전체 = subset['가맹점수'].sum()

    # topn 지정 (없으면 전체)
    if topn:
        subset = subset.head(topn)
    
    print(f"\n-- {업종명} 업종의 상권 분포 ({'Top '+str(topn) if topn else '전체'}) ---")
    print(f"전체 가맹점 수: {전체}개")
    
    for _, row in subset.iterrows():
        print(f"{row['상권']}: {row['상권비율(%)']:.1f}% ({int(row['가맹점수'])}개)")
# 업종별 전체 가맹점수 기준 내림차순 정렬
업종순서 = (
    업종_상권분포.groupby('업종')['가맹점수']
          .sum()
          .sort_values(ascending=False)
          .index
)

# 정렬된 순서대로 출력
for 업종명 in 업종순서:
    업종기준_출력(업종명, topn=5)
# Out:
# -- 한식-육류/고기 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 430개
# 왕십리: 25.8% (111개)
# 성수: 22.1% (95개)
# 마장동: 13.3% (57개)
# 한양대: 10.5% (45개)
# 뚝섬: 7.9% (34개)
#
# -- 카페 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 343개
# 성수: 35.6% (122개)
# 뚝섬: 19.2% (66개)
# 왕십리: 15.5% (53개)
# 한양대: 6.7% (23개)
# 옥수: 5.5% (19개)
#
# -- 백반/가정식 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 342개
# 성수: 32.2% (110개)
# 왕십리: 20.5% (70개)
# 뚝섬: 11.4% (39개)
# 마장동: 7.3% (25개)
# 금남시장: 6.7% (23개)
#
# -- 한식-단품요리일반 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 288개
# 성수: 29.2% (84개)
# 왕십리: 21.5% (62개)
# 한양대: 13.5% (39개)
# 뚝섬: 11.1% (32개)
# 금남시장: 8.0% (23개)
#
# -- 축산물 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 278개
# 마장동: 76.3% (212개)
# 왕십리: 9.7% (27개)
# 성수: 3.2% (9개)
# 금남시장: 2.9% (8개)
# 답십리: 2.2% (6개)
#
# -- 커피전문점 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 177개
# 성수: 31.1% (55개)
# 왕십리: 20.3% (36개)
# 뚝섬: 15.3% (27개)
# 한양대: 9.0% (16개)
# 마장동: 6.2% (11개)
#
# -- 양식 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 169개
# 성수: 42.6% (72개)
# 뚝섬: 21.9% (37개)
# 왕십리: 12.4% (21개)
# 금남시장: 5.9% (10개)
# 옥수: 5.9% (10개)
#
# -- 식료품 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 152개
# 성수: 27.6% (42개)
# 왕십리: 19.7% (30개)
# 마장동: 13.2% (20개)
# 금남시장: 8.6% (13개)
# 뚝섬: 7.2% (11개)
#
# -- 베이커리 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 140개
# 성수: 30.0% (42개)
# 왕십리: 22.1% (31개)
# 뚝섬: 12.1% (17개)
# 옥수: 8.6% (12개)
# 한양대: 7.1% (10개)
#
# -- 분식 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 134개
# 왕십리: 23.1% (31개)
# 성수: 18.7% (25개)
# 한양대: 10.4% (14개)
# 뚝섬: 9.7% (13개)
# 마장동: 9.0% (12개)
#
# -- 치킨 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 132개
# 왕십리: 26.5% (35개)
# 성수: 19.7% (26개)
# 금남시장: 12.1% (16개)
# 마장동: 9.1% (12개)
# 한양대: 7.6% (10개)
#
# -- 일식당 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 128개
# 성수: 33.6% (43개)
# 왕십리: 22.7% (29개)
# 뚝섬: 13.3% (17개)
# 한양대: 8.6% (11개)
# 금남시장: 5.5% (7개)
#
# -- 한식-해물/생선 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 116개
# 성수: 28.4% (33개)
# 왕십리: 22.4% (26개)
# 뚝섬: 10.3% (12개)
# 금남시장: 10.3% (12개)
# 답십리: 9.5% (11개)
#
# -- 중식당 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 94개
# 성수: 34.0% (32개)
# 왕십리: 14.9% (14개)
# 뚝섬: 12.8% (12개)
# 한양대: 7.4% (7개)
# 금남시장: 6.4% (6개)
#
# -- 호프/맥주 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 83개
# 왕십리: 26.5% (22개)
# 성수: 19.3% (16개)
# 한양대: 15.7% (13개)
# 마장동: 12.0% (10개)
# 금남시장: 7.2% (6개)
#
# -- 요리주점 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 77개
# 성수: 33.8% (26개)
# 왕십리: 20.8% (16개)
# 한양대: 11.7% (9개)
# 금남시장: 10.4% (8개)
# 뚝섬: 10.4% (8개)
#
# -- 한식-국수/만두 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 64개
# 성수: 35.9% (23개)
# 왕십리: 20.3% (13개)
# 뚝섬: 12.5% (8개)
# 답십리: 9.4% (6개)
# 금남시장: 4.7% (3개)
#
# -- 아이스크림/빙수 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 60개
# 성수: 23.3% (14개)
# 왕십리: 15.0% (9개)
# 한양대: 11.7% (7개)
# 금남시장: 11.7% (7개)
# 마장동: 11.7% (7개)
#
# -- 농산물 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 59개
# 왕십리: 27.1% (16개)
# 답십리: 16.9% (10개)
# 성수: 16.9% (10개)
# 마장동: 15.3% (9개)
# 금남시장: 13.6% (8개)
#
# -- 한식-국밥/설렁탕 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 59개
# 성수: 39.0% (23개)
# 왕십리: 27.1% (16개)
# 뚝섬: 10.2% (6개)
# 금남시장: 5.1% (3개)
# 마장동: 5.1% (3개)
#
# -- 피자 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 49개
# 성수: 32.7% (16개)
# 왕십리: 20.4% (10개)
# 한양대: 14.3% (7개)
# 마장동: 10.2% (5개)
# 옥수: 6.1% (3개)
#
# -- 한식-찌개/전골 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 48개
# 왕십리: 20.8% (10개)
# 성수: 20.8% (10개)
# 뚝섬: 16.7% (8개)
# 한양대: 12.5% (6개)
# 답십리: 8.3% (4개)
#
# -- 일반 유흥주점 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 44개
# 왕십리: 36.4% (16개)
# 성수: 31.8% (14개)
# 뚝섬: 18.2% (8개)
# 장한평자동차: 4.5% (2개)
# 금남시장: 2.3% (1개)
#
# -- 포장마차 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 41개
# 한양대: 29.3% (12개)
# 왕십리: 29.3% (12개)
# 금남시장: 19.5% (8개)
# 성수: 7.3% (3개)
# 신금호: 4.9% (2개)
#
# -- 이자카야 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 37개
# 성수: 32.4% (12개)
# 뚝섬: 16.2% (6개)
# 왕십리: 16.2% (6개)
# 한양대: 13.5% (5개)
# 금남시장: 10.8% (4개)
#
# -- 일식-덮밥/돈가스 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 33개
# 성수: 27.3% (9개)
# 뚝섬: 24.2% (8개)
# 왕십리: 21.2% (7개)
# 한양대: 15.2% (5개)
# 옥수: 9.1% (3개)
#
# -- 샌드위치/토스트 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 31개
# 성수: 45.2% (14개)
# 한양대: 16.1% (5개)
# 왕십리: 12.9% (4개)
# 뚝섬: 12.9% (4개)
# 금남시장: 6.5% (2개)
#
# -- 동남아/인도음식 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 31개
# 성수: 29.0% (9개)
# 왕십리: 25.8% (8개)
# 뚝섬: 25.8% (8개)
# 옥수: 6.5% (2개)
# 금남시장: 6.5% (2개)
#
# -- 햄버거 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 30개
# 왕십리: 30.0% (9개)
# 성수: 26.7% (8개)
# 뚝섬: 16.7% (5개)
# 한양대: 10.0% (3개)
# 금남시장: 3.3% (1개)
#
# -- 청과물 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 27개
# 왕십리: 22.2% (6개)
# 금남시장: 14.8% (4개)
# 행당: 14.8% (4개)
# 답십리: 11.1% (3개)
# 마장동: 11.1% (3개)
#
# -- 와인바 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 26개
# 성수: 50.0% (13개)
# 뚝섬: 34.6% (9개)
# 옥수: 7.7% (2개)
# 금남시장: 3.8% (1개)
# 한양대: 3.8% (1개)
#
# -- 룸살롱/단란주점 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 22개
# 왕십리: 45.5% (10개)
# 금남시장: 18.2% (4개)
# 마장동: 18.2% (4개)
# 성수: 9.1% (2개)
# 한양대: 9.1% (2개)
#
# -- 떡/한과 제조 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 22개
# 왕십리: 22.7% (5개)
# 금남시장: 13.6% (3개)
# 행당: 13.6% (3개)
# 답십리: 9.1% (2개)
# 뚝섬: 9.1% (2개)
#
# -- 반찬 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 22개
# 왕십리: 22.7% (5개)
# 금남시장: 18.2% (4개)
# 뚝섬: 18.2% (4개)
# 행당: 13.6% (3개)
# 마장동: 9.1% (2개)
#
# -- 한식-냉면 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 17개
# 성수: 23.5% (4개)
# 금남시장: 17.6% (3개)
# 신금호: 11.8% (2개)
# 답십리: 11.8% (2개)
# 왕십리: 11.8% (2개)
#
# -- 식품 제조 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 17개
# 성수: 29.4% (5개)
# 금남시장: 17.6% (3개)
# 뚝섬: 17.6% (3개)
# 왕십리: 11.8% (2개)
# 마장동: 5.9% (1개)
#
# -- 한식뷔페 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 16개
# 성수: 56.2% (9개)
# 왕십리: 18.8% (3개)
# 답십리: 12.5% (2개)
# 뚝섬: 6.2% (1개)
# 장한평자동차: 6.2% (1개)
#
# -- 주류 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 15개
# 왕십리: 33.3% (5개)
# 옥수: 20.0% (3개)
# 뚝섬: 13.3% (2개)
# 성수: 13.3% (2개)
# 금남시장: 6.7% (1개)
#
# -- 꼬치구이 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 14개
# 성수: 35.7% (5개)
# 왕십리: 21.4% (3개)
# 한양대: 21.4% (3개)
# 답십리: 7.1% (1개)
# 뚝섬: 7.1% (1개)
#
# -- 한식-감자탕 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 13개
# 왕십리: 23.1% (3개)
# 마장동: 15.4% (2개)
# 뚝섬: 15.4% (2개)
# 신금호: 15.4% (2개)
# 성수: 15.4% (2개)
#
# -- 건강식품 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 12개
# 왕십리: 33.3% (4개)
# 금남시장: 25.0% (3개)
# 행당: 16.7% (2개)
# 마장동: 8.3% (1개)
# 압구정로데오: 8.3% (1개)
#
# -- 인삼제품 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 12개
# 왕십리: 41.7% (5개)
# 성수: 16.7% (2개)
# 마장동: 16.7% (2개)
# 행당: 16.7% (2개)
# 뚝섬: 8.3% (1개)
#
# -- 일식-우동/소바/라면 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 11개
# 성수: 36.4% (4개)
# 한양대: 27.3% (3개)
# 답십리: 9.1% (1개)
# 금남시장: 9.1% (1개)
# 옥수: 9.1% (1개)
#
# -- 미곡상 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 10개
# 금남시장: 20.0% (2개)
# 답십리: 20.0% (2개)
# 옥수: 20.0% (2개)
# 성수: 10.0% (1개)
# 신금호: 10.0% (1개)
#
# -- 담배 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 10개
# 왕십리: 50.0% (5개)
# 성수: 20.0% (2개)
# 금남시장: 10.0% (1개)
# 뚝섬: 10.0% (1개)
# 한양대: 10.0% (1개)
#
# -- 기타세계요리 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 10개
# 왕십리: 30.0% (3개)
# 성수: 30.0% (3개)
# 뚝섬: 10.0% (1개)
# 답십리: 10.0% (1개)
# 신금호: 10.0% (1개)
#
# -- 한식-죽 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 9개
# 성수: 22.2% (2개)
# 왕십리: 22.2% (2개)
# 금남시장: 11.1% (1개)
# 뚝섬: 11.1% (1개)
# 신금호: 11.1% (1개)
#
# -- 건강원 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 9개
# 금남시장: 22.2% (2개)
# 성수: 22.2% (2개)
# 신금호: 22.2% (2개)
# 왕십리: 22.2% (2개)
# 행당: 11.1% (1개)
#
# -- 일식-초밥/롤 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 7개
# 성수: 42.9% (3개)
# 뚝섬: 28.6% (2개)
# 신금호: 14.3% (1개)
# 옥수: 14.3% (1개)
#
# -- 도시락 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 7개
# 한양대: 42.9% (3개)
# 뚝섬: 14.3% (1개)
# 마장동: 14.3% (1개)
# 왕십리: 14.3% (1개)
# 행당: 14.3% (1개)
#
# -- 일식-샤브샤브 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 6개
# 왕십리: 50.0% (3개)
# 뚝섬: 33.3% (2개)
# 금남시장: 16.7% (1개)
#
# -- 수산물 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 6개
# 금남시장: 33.3% (2개)
# 왕십리: 33.3% (2개)
# 뚝섬: 16.7% (1개)
# 옥수: 16.7% (1개)
#
# -- 일식-참치회 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 6개
# 성수: 33.3% (2개)
# 옥수: 33.3% (2개)
# 답십리: 16.7% (1개)
# 왕십리: 16.7% (1개)
#
# -- 떡/한과 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 5개
# 성수: 40.0% (2개)
# 왕십리: 40.0% (2개)
# 옥수: 20.0% (1개)
#
# -- 한정식 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 4개
# 성수: 50.0% (2개)
# 뚝섬: 25.0% (1개)
# 장한평자동차: 25.0% (1개)
#
# -- 도너츠 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 4개
# 뚝섬: 50.0% (2개)
# 왕십리: 50.0% (2개)
#
# -- 중식-훠궈/마라탕 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 4개
# 금남시장: 25.0% (1개)
# 왕십리: 25.0% (1개)
# 한양대: 25.0% (1개)
# 행당: 25.0% (1개)
#
# -- 차 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 4개
# 왕십리: 50.0% (2개)
# 뚝섬: 25.0% (1개)
# 한양대: 25.0% (1개)
#
# -- 와인샵 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 3개
# 성수: 66.7% (2개)
# 옥수: 33.3% (1개)
#
# -- 주스 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 3개
# 뚝섬: 33.3% (1개)
# 옥수: 33.3% (1개)
# 한양대: 33.3% (1개)
#
# -- 마카롱 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 3개
# 금남시장: 33.3% (1개)
# 답십리: 33.3% (1개)
# 왕십리: 33.3% (1개)
#
# -- 테마카페 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 2개
# 금남시장: 50.0% (1개)
# 왕십리: 50.0% (1개)
#
# -- 테이크아웃커피 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 2개
# 답십리: 50.0% (1개)
# 뚝섬: 50.0% (1개)
#
# -- 건어물 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 2개
# 금남시장: 100.0% (2개)
#
# -- 민속주점 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 2개
# 뚝섬: 50.0% (1개)
# 성수: 50.0% (1개)
#
# -- 중식-딤섬/중식만두 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 2개
# 뚝섬: 50.0% (1개)
# 성수: 50.0% (1개)
#
# -- 기사식당 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 1개
# 장한평자동차: 100.0% (1개)
#
# -- 구내식당/푸드코트 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 1개
# 왕십리: 100.0% (1개)
#
# -- 스테이크 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 1개
# 성수: 100.0% (1개)
#
# -- 유제품 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 1개
# 마장동: 100.0% (1개)
#
# -- 와플/크로플 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 1개
# 뚝섬: 100.0% (1개)
#
# -- 탕후루 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 1개
# 왕십리: 100.0% (1개)
#
# -- 한식-두부요리 업종의 상권 분포 (Top 5) ---
# 전체 가맹점 수: 1개
# 옥수: 100.0% (1개)

# %%
import pandas as pd
import numpy as np

# -----------------------------------------
# 1️⃣ 고객 관련 컬럼 설정
# -----------------------------------------
고객컬럼 = [
    '남성 20대이하 고객 비중', '남성 30대 고객 비중', '남성 40대 고객 비중', 
    '남성 50대 고객 비중', '남성 60대이상 고객 비중',
    '여성 20대이하 고객 비중', '여성 30대 고객 비중', '여성 40대 고객 비중',
    '여성 50대 고객 비중', '여성 60대이상 고객 비중'
]

# 음수값 NaN 처리
df[고객컬럼] = df[고객컬럼].applymap(lambda x: np.nan if x < 0 else x)

# -----------------------------------------
# 2️⃣ 업종별 평균 비율 계산
# -----------------------------------------
업종별_고객평균 = df.groupby('업종')[고객컬럼].mean().reset_index()

# -----------------------------------------
# 3️⃣ 상위 3개 핵심고객층 분리 저장
# -----------------------------------------
결과리스트 = []

for _, row in 업종별_고객평균.iterrows():
    업종명 = row['업종']
    고객비중 = row[고객컬럼].dropna().sort_values(ascending=False)
    
    # 상위 3개 추출 (부족하면 NaN으로 채움)
    top = [f"{col.replace(' 고객 비중','')} ({val:.1f}%)" for col, val in 고객비중.head(3).items()]
    while len(top) < 3:
        top.append(np.nan)
    
    결과리스트.append({
        '업종': 업종명,
        '핵심고객층1': top[0],
        '핵심고객층2': top[1],
        '핵심고객층3': top[2]
    })

업종별_핵심고객 = pd.DataFrame(결과리스트)
업종별_핵심고객.to_excel('업종별_핵심고객층.xlsx', index=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_145712\1459555560.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[고객컬럼] = df[고객컬럼].applymap(lambda x: np.nan if x < 0 else x)

# %%
import pandas as pd
import numpy as np

# -----------------------------------------
# 1️⃣ 분석 대상 컬럼 설정
# -----------------------------------------
cols = [
    '재방문 고객 비중',
    '신규 고객 비중',
    '거주 이용 고객 비율',
    '직장 이용 고객 비율',
    '유동인구 이용 고객 비율'
]

# -----------------------------------------
# 2️⃣ 음수값 NaN 처리
# -----------------------------------------
df[cols] = df[cols].applymap(lambda x: np.nan if x < 0 else x)

# -----------------------------------------
# 3️⃣ 업종별 평균 계산
# -----------------------------------------
업종별_패턴 = (
    df.groupby('업종')[cols]
      .mean()
      .reset_index()
      .round(1)
)

# -----------------------------------------
# 4️⃣ 재방문 고객 비중 기준 내림차순 정렬
# -----------------------------------------
업종별_패턴 = 업종별_패턴.sort_values('재방문 고객 비중', ascending=False)

업종별_패턴.to_excel('업종별_고객패턴.xlsx', index=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_145712\481046133.py:18: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[cols] = df[cols].applymap(lambda x: np.nan if x < 0 else x)

# %%
#운영기간별 매출규모
#운영기간별 매출건수추이
#배달매출 비중 분석
# -----------------------------------------
# 1️⃣ 분석 대상 컬럼 지정
# -----------------------------------------
cols = ['업종', '가맹점 운영개월수 구간', '매출금액 구간', '매출건수 구간', '배달매출금액 비율']

# 음수값 NaN 처리
df[cols] = df[cols].applymap(lambda x: np.nan if isinstance(x, (int, float)) and x < 0 else x)

# -----------------------------------------
# 2️⃣ 업종별·운영개월별 평균 계산
# -----------------------------------------
업종별_운영개월_추이 = (
    df.groupby(['업종', '가맹점 운영개월수 구간'])[['매출금액 구간', '매출건수 구간', '배달매출금액 비율']]
      .mean()
      .reset_index()
      .sort_values(['업종', '가맹점 운영개월수 구간'])
)

업종별_운영개월_추이.to_excel('업종별_운영개월구간별 매출_추이.xlsx', index=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_145712\3206414338.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[cols] = df[cols].applymap(lambda x: np.nan if isinstance(x, (int, float)) and x < 0 else x)

# %%
import matplotlib.pyplot as plt

# 예시 업종
target = '건강식품'
subset = 업종별_운영개월_추이[업종별_운영개월_추이['업종'] == target]

plt.figure(figsize=(8,5))
plt.plot(subset['가맹점 운영개월수 구간'], subset['매출금액 구간'], marker='o', label='매출금액 구간')
plt.plot(subset['가맹점 운영개월수 구간'], subset['매출건수 구간'], marker='o', label='매출건수 구간')
plt.xticks(rotation=45)
plt.title(f"{target} 업종의 운영기간별 매출 추이")
plt.legend()
plt.show()

# %% [markdown]
# ## 기존

# %%
df['기준년월'] = pd.to_datetime(df['기준년월'], format='%Y%m')

# %%
# 매출건수 구간별 빈도
count_trend = (
    df.groupby(['기준년월', '업종', '매출건수 구간'])
      .size()
      .reset_index(name='count')
)

# 매출금액 구간별 빈도
amount_trend = (
    df.groupby(['기준년월', '업종', '매출금액 구간'])
      .size()
      .reset_index(name='count')
)
count_trend, amount_trend
# Out:
# (           기준년월     업종  매출건수 구간  count
#  0    2023-01-01   건강식품        4      2
#  1    2023-01-01   건강식품        5      4
#  2    2023-01-01   건강식품        6      3
#  3    2023-01-01    건강원        4      1
#  4    2023-01-01    건강원        5      2
#  ...         ...    ...      ...    ...
#  6806 2024-12-01  호프/맥주        2      6
#  6807 2024-12-01  호프/맥주        3     17
#  6808 2024-12-01  호프/맥주        4     32
#  6809 2024-12-01  호프/맥주        5     20
#  6810 2024-12-01  호프/맥주        6      8
#
#  [6811 rows x 4 columns],
#             기준년월     업종  매출금액 구간  count
#  0    2023-01-01   건강식품        1      1
#  1    2023-01-01   건강식품        5      5
#  2    2023-01-01   건강식품        6      3
#  3    2023-01-01    건강원        5      3
#  4    2023-01-01    건강원        6      5
#  ...         ...    ...      ...    ...
#  7166 2024-12-01  호프/맥주        2     13
#  7167 2024-12-01  호프/맥주        3     23
#  7168 2024-12-01  호프/맥주        4     18
#  7169 2024-12-01  호프/맥주        5     17
#  7170 2024-12-01  호프/맥주        6      8
#
#  [7171 rows x 4 columns])

# %%
import pandas as pd
import numpy as np

# --------------------------
# 1️⃣ 구간 문자열을 평균값으로 변환하는 함수
# --------------------------
def 구간평균(값):
    if pd.isna(값):
        return np.nan
    # '0~10' 같은 형태 처리
    if '~' in str(값):
        시작, 끝 = str(값).split('~')
        try:
            return (float(시작) + float(끝)) / 2
        except:
            return np.nan
    # 이미 숫자이거나 변환 불가한 값은 그대로 반환
    try:
        return float(값)
    except:
        return np.nan

# --------------------------
# 2️⃣ 구간을 숫자 평균으로 변환
# --------------------------
df['매출건수_평균'] = df['매출건수 구간'].apply(구간평균)
df['매출금액_평균'] = df['매출금액 구간'].apply(구간평균)

# --------------------------
# 3️⃣ 월별 · 업종별 평균 계산
# --------------------------
count_trend = (
    df.groupby(['기준년월', '업종'])['매출건수_평균']
          .mean()
          .reset_index(name='매출건수_평균')
)

amount_trend = (
    df.groupby(['기준년월', '업종'])['매출금액_평균']
          .mean()
          .reset_index(name='매출금액_평균')
)

count_trend.sort_values(['업종', '기준년월'], inplace=True)
count_trend
# Out:
#            기준년월     업종   매출건수_평균
# 0    2023-01-01   건강식품  5.111111
# 71   2023-02-01   건강식품  5.444444
# 142  2023-03-01   건강식품  5.333333
# 213  2023-04-01   건강식품  5.444444
# 284  2023-05-01   건강식품  5.000000
# ...         ...    ...       ...
# 1447 2024-08-01  호프/맥주  3.950617
# 1520 2024-09-01  호프/맥주  4.012195
# 1593 2024-10-01  호프/맥주  4.012048
# 1666 2024-11-01  호프/맥주  4.072289
# 1739 2024-12-01  호프/맥주  4.084337
#
# [1740 rows x 3 columns]

# %%
count_trend.to_excel('업종별_월별_매출건수_평균.xlsx', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# 1️⃣ 기준년월을 날짜형으로 변환
count_trend['기준년월'] = pd.to_datetime(count_trend['기준년월'])

# 2️⃣ 표시용 라벨 컬럼 추가 (예: 2024-01 → 24.1)
count_trend['표시용_월'] = count_trend['기준년월'].apply(lambda x: f"{x.year % 100}.{x.month}")

# 3️⃣ 고유 업종 리스트
업종목록 = sorted(count_trend['업종'].unique())

# 4️⃣ subplot 행·열 구성 (4개씩)
cols = 4
rows = math.ceil(len(업종목록) / cols)

# 5️⃣ 그래프 그리기
fig, axes = plt.subplots(rows, cols, figsize=(20, 5 * rows))
axes = axes.flatten()

for i, 업종 in enumerate(업종목록):
    data = count_trend[count_trend['업종'] == 업종]
    
    sns.lineplot(
        data=data, x='표시용_월', y='매출건수_평균',
        marker='o', ax=axes[i], color='steelblue'
    )
    axes[i].set_title(f'{업종}', fontsize=13)
    axes[i].set_xlabel('기준년월', fontsize=11)
    axes[i].set_ylabel('매출건수 평균', fontsize=11)
    axes[i].grid(True, alpha=0.3)
    axes[i].tick_params(axis='x', rotation=45)  # x축 레이블 기울이기

# 6️⃣ 남는 subplot 제거
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.suptitle('업종별 월별 매출건수 평균 추이', fontsize=16, y=1.02)
plt.show()

# %% [markdown]
# # 상권별

# %%
import pandas as pd
import numpy as np

# --------------------------
# 1️⃣ 구간 문자열을 평균값으로 변환하는 함수
# --------------------------
def 구간평균(값):
    if pd.isna(값):
        return np.nan
    # '0~10' 같은 형태 처리
    if '~' in str(값):
        시작, 끝 = str(값).split('~')
        try:
            return (float(시작) + float(끝)) / 2
        except:
            return np.nan
    # 이미 숫자이거나 변환 불가한 값은 그대로 반환
    try:
        return float(값)
    except:
        return np.nan

# --------------------------
# 2️⃣ 구간을 숫자 평균으로 변환
# --------------------------
df['매출건수_평균'] = df['매출건수 구간'].apply(구간평균)
df['매출금액_평균'] = df['매출금액 구간'].apply(구간평균)

# --------------------------
# 3️⃣ 월별 · 상권별 평균 계산
# --------------------------
count_area = (
    df.groupby(['기준년월', '상권'])['매출건수_평균']
          .mean()
          .reset_index(name='매출건수_평균')
)

amount_trend = (
    df.groupby(['기준년월', '상권'])['매출금액_평균']
          .mean()
          .reset_index(name='매출금액_평균')
)

count_area.sort_values(['상권', '기준년월'], inplace=True)
count_area
